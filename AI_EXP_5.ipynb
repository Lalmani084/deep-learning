# %%
from textblob import TextBlob
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
import pandas as pd

# %%
df_experience = pd.read_csv("/content/sentiment_analysis_poem.csv")

# %%
df_experience['Text'][0]
# Out:
# ' Enjoying a beautiful day at the park!              '

# %%
TextBlob(df_experience['Text'][10])
# Out:
# TextBlob(" Just published a new blog post. Check it out!      ")

# %%
TextBlob(df_experience['Text'][10]).sentiment
# Out:
# Sentiment(polarity=0.17045454545454544, subjectivity=0.45454545454545453)

# %%
df_experience['Polarity']=df_experience['Text'].apply(lambda x:TextBlob(x).polarity)
df_experience
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 0               0           0
# 1               1           1
# 2               2           2
# 3               3           3
# 4               4           4
# ..            ...         ...
# 727           728         732
# 728           729         733
# 729           730         734
# 730           731         735
# 731           732         736
#
#                                                   Text    Sentiment  \
# 0     Enjoying a beautiful day at the park!        ...   Positive
# 1     Traffic was terrible this morning.           ...   Negative
# 2     Just finished an amazing workout! 💪          ...   Positive
# 3     Excited about the upcoming weekend getaway!  ...   Positive
# 4     Trying out a new recipe for dinner tonight.  ...   Neutral
# ..                                                 ...          ...
# 727  Collaborating on a science project that receiv...       Happy
# ...

# %%
df_experience['Subjectivity']=df_experience['Text'].apply(lambda x:TextBlob(x).subjectivity)
df_experience
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 0               0           0
# 1               1           1
# 2               2           2
# 3               3           3
# 4               4           4
# ..            ...         ...
# 727           728         732
# 728           729         733
# 729           730         734
# 730           731         735
# 731           732         736
#
#                                                   Text    Sentiment  \
# 0     Enjoying a beautiful day at the park!        ...   Positive
# 1     Traffic was terrible this morning.           ...   Negative
# 2     Just finished an amazing workout! 💪          ...   Positive
# 3     Excited about the upcoming weekend getaway!  ...   Positive
# 4     Trying out a new recipe for dinner tonight.  ...   Neutral
# ..                                                 ...          ...
# 727  Collaborating on a science project that receiv...       Happy
# ...

# %%
df_experience['Sentiment'] = df_experience['Polarity'].apply(lambda x : "Positive" if x > 0 else "Neutral" if x ==0 else "Negative")
df_experience
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 0               0           0
# 1               1           1
# 2               2           2
# 3               3           3
# 4               4           4
# ..            ...         ...
# 727           728         732
# 728           729         733
# 729           730         734
# 730           731         735
# 731           732         736
#
#                                                   Text Sentiment  \
# 0     Enjoying a beautiful day at the park!        ...  Positive
# 1     Traffic was terrible this morning.           ...  Negative
# 2     Just finished an amazing workout! 💪          ...  Positive
# 3     Excited about the upcoming weekend getaway!  ...  Positive
# 4     Trying out a new recipe for dinner tonight.  ...  Positive
# ..                                                 ...       ...
# 727  Collaborating on a science project that receiv...  Positive
# 728  Attending a surprise birthday party organized ...  Positive
# ...

# %%
sentiment_counts = df_experience['Sentiment']. value_counts()
sentiment_counts
# Out:
# Sentiment
# Neutral     324
# Positive    282
# Negative    126
# Name: count, dtype: int64

# %%
sentiment_counts.plot(kind='bar')
plt.title('Sentiment Analysis')
plt.xlabel("Sentiment")
plt.ylabel("Count")
plt.show()
